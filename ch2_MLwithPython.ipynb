# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sabumjung/Tensorflow/blob/master/ch2_MLwithPython.ipynb)

# %%
#2장-1
import numpy as np
import matplotlib.pylab as plt

nb_samples=100
X_data=np.random.normal(loc=0.0, scale=np.sqrt(2.0), size=nb_samples)
plt.plot(X_data)
